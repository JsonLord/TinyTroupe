# %% [markdown]
# # Simple Chat
#
# A simple demonstration of two agents talking to each other.

# %%
import json
import sys
sys.path.insert(0, '..')

import tinytroupe
from tinytroupe.agent import TinyPerson
from tinytroupe.environment import TinyWorld, TinySocialNetwork
from tinytroupe.examples import *
# Out:
# !!!!
# DISCLAIMER: TinyTroupe relies on Artificial Intelligence (AI) models to generate content.
# The AI models are not perfect and may produce inappropriate or inacurate results.
# For any serious or consequential use, please review the generated content before using it.
# !!!!
#
# Looking for default config on: /app/examples/../tinytroupe/utils/../config.ini
# Found custom config on: /app/examples/config.ini
# TinyTroupe version: 0.5.2
# Current date and time (local): 2025-12-02 16:32:32
# Current date and time (UTC):   2025-12-02 16:32:32
#
# =================================
# Current TinyTroupe configuration
# =================================
# [OpenAI]
# api_type = helmholtz-blablador
# azure_api_version = 2023-05-15
# blablador_endpoint = https://api.helmholtz-blablador.fz-juelich.de/v1
# model = alias-fast
# reasoning_model = alias-large
# embedding_model = text-embedding-3-small
# max_tokens = 32000
# temperature = 0.1
# top_p = 0.9
# freq_penalty = 0.1
# presence_penalty = 0.1
# timeout = 480
# max_attempts = 5
# waiting_time = 25.0
# exponential_backoff_factor = 5
# reasoning_effort = high
# cache_api_calls = False
# cache_file_name = openai_api_cache.pickle
# max_content_display_length = 4000
#
# [Simulation]
# parallel_agent_generation = True
# parallel_agent_actions = True
# rai_harmful_content_prevention = True
# rai_copyright_infringement_prevention = True
#
# [Cognition]
# enable_memory_consolidation = True
# min_episode_length = 15
# max_episode_length = 50
# episodic_memory_fixed_prefix_length = 10
# episodic_memory_lookback_length = 20
#
# [ActionGenerator]
# max_attempts = 2
# enable_quality_checks = False
# enable_regeneration = True
# enable_direct_correction = False
# enable_quality_check_for_persona_adherence = True
# enable_quality_check_for_selfconsistency = False
# enable_quality_check_for_fluency = False
# enable_quality_check_for_suitability = False
# enable_quality_check_for_similarity = False
# continue_on_failure = True
# quality_threshold = 5
#
# [Logging]
# loglevel = INFO

# %%
lisa = TinyPerson.load_specification("./agents/Lisa.agent.json")  # Lisa, the data scientist
oscar = TinyPerson.load_specification("./agents/Oscar.agent.json")  # Oscar, the architect

# %%
world = TinyWorld("Chat Room", [lisa, oscar])
world.make_everyone_accessible()

# %%
lisa.listen("Talk to Oscar to know more about him")
world.run(4)
# Out:
# INFO     [Lisa Carter] Output: [bold italic cyan1][underline]USER[/] --> [bold italic cyan1][underline]Lisa Carter[/]: [CONVERSATION]
#           > Talk to Oscar to know more about him[/]
# USER --> Lisa Carter: [CONVERSATION]
#           > Talk to Oscar to know more about him
# 2025-12-02 16:32:38,533 - tinytroupe - INFO - [Chat Room] Running world simulation step 1 of 4.
# ────────────────────────────────────────────── Chat Room step 1 of 4 ──────────────────────────────────────────────
# 2025-12-02 16:32:38,541 - tinytroupe - INFO - [Chat Room] No timedelta provided, so the datetime was not advanced.
# 2025-12-02 16:32:38,549 - tinytroupe - WARNING - BLABLADOR_API_KEY not set. Falling back to OpenAI client.
# 2025-12-02 16:32:38,551 - tinytroupe - INFO - Configuring for OpenAIClient.
# INFO     [root] Updated config: model = gpt-4o-mini
# 2025-12-02 16:32:38,554 - tinytroupe - WARNING - BLABLADOR_API_KEY not set. Falling back to OpenAI client.
# 2025-12-02 16:32:38,559 - tinytroupe - INFO - Configuring for OpenAIClient.
# INFO     [root] Updated config: reasoning_model = gpt-4
# INFO     [root] Updated config: max_tokens = 16384
# INFO     [root] Updated config: model = gpt-4o-mini
# INFO     [root] Updated config: reasoning_model = gpt-4
# INFO     [root] Updated config: max_tokens = 16384
# 2025-12-02 16:32:38,570 - tinytroupe - ERROR - [Chat Room] Agent Lisa Carter generated an exception: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# 2025-12-02 16:32:38,572 - tinytroupe - ERROR - [Chat Room] Agent Oscar generated an exception: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# 2025-12-02 16:32:38,574 - tinytroupe - INFO - [Chat Room] Running world simulation step 2 of 4.
# ────────────────────────────────────────────── Chat Room step 2 of 4 ──────────────────────────────────────────────
# 2025-12-02 16:32:38,580 - tinytroupe - INFO - [Chat Room] No timedelta provided, so the datetime was not advanced.
# 2025-12-02 16:32:38,588 - tinytroupe - WARNING - BLABLADOR_API_KEY not set. Falling back to OpenAI client.
# 2025-12-02 16:32:38,592 - tinytroupe - WARNING - BLABLADOR_API_KEY not set. Falling back to OpenAI client.
# 2025-12-02 16:32:38,592 - tinytroupe - INFO - Configuring for OpenAIClient.
# INFO     [root] Updated config: model = gpt-4o-mini
# 2025-12-02 16:32:38,594 - tinytroupe - INFO - Configuring for OpenAIClient.
# INFO     [root] Updated config: model = gpt-4o-mini
# INFO     [root] Updated config: reasoning_model = gpt-4
# INFO     [root] Updated config: reasoning_model = gpt-4
# INFO     [root] Updated config: max_tokens = 16384
# INFO     [root] Updated config: max_tokens = 16384
# 2025-12-02 16:32:38,606 - tinytroupe - ERROR - [Chat Room] Agent Lisa Carter generated an exception: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# 2025-12-02 16:32:38,607 - tinytroupe - ERROR - [Chat Room] Agent Oscar generated an exception: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# 2025-12-02 16:32:38,609 - tinytroupe - INFO - [Chat Room] Running world simulation step 3 of 4.
# ────────────────────────────────────────────── Chat Room step 3 of 4 ──────────────────────────────────────────────
# 2025-12-02 16:32:38,613 - tinytroupe - INFO - [Chat Room] No timedelta provided, so the datetime was not advanced.
# 2025-12-02 16:32:38,620 - tinytroupe - WARNING - BLABLADOR_API_KEY not set. Falling back to OpenAI client.
# 2025-12-02 16:32:38,622 - tinytroupe - WARNING - BLABLADOR_API_KEY not set. Falling back to OpenAI client.
# 2025-12-02 16:32:38,624 - tinytroupe - INFO - Configuring for OpenAIClient.
# INFO     [root] Updated config: model = gpt-4o-mini
# 2025-12-02 16:32:38,622 - tinytroupe - INFO - Configuring for OpenAIClient.
# INFO     [root] Updated config: reasoning_model = gpt-4
# INFO     [root] Updated config: model = gpt-4o-mini
# INFO     [root] Updated config: reasoning_model = gpt-4
# INFO     [root] Updated config: max_tokens = 16384
# INFO     [root] Updated config: max_tokens = 16384
# 2025-12-02 16:32:38,633 - tinytroupe - ERROR - [Chat Room] Agent Lisa Carter generated an exception: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# 2025-12-02 16:32:38,634 - tinytroupe - ERROR - [Chat Room] Agent Oscar generated an exception: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# 2025-12-02 16:32:38,635 - tinytroupe - INFO - [Chat Room] Running world simulation step 4 of 4.
# ────────────────────────────────────────────── Chat Room step 4 of 4 ──────────────────────────────────────────────
# 2025-12-02 16:32:38,639 - tinytroupe - INFO - [Chat Room] No timedelta provided, so the datetime was not advanced.
# 2025-12-02 16:32:38,643 - tinytroupe - WARNING - BLABLADOR_API_KEY not set. Falling back to OpenAI client.
# 2025-12-02 16:32:38,644 - tinytroupe - INFO - Configuring for OpenAIClient.
# INFO     [root] Updated config: model = gpt-4o-mini
# INFO     [root] Updated config: reasoning_model = gpt-4
# INFO     [root] Updated config: max_tokens = 16384
# 2025-12-02 16:32:38,658 - tinytroupe - WARNING - BLABLADOR_API_KEY not set. Falling back to OpenAI client.
# 2025-12-02 16:32:38,660 - tinytroupe - INFO - Configuring for OpenAIClient.
# INFO     [root] Updated config: model = gpt-4o-mini
# INFO     [root] Updated config: reasoning_model = gpt-4
# INFO     [root] Updated config: max_tokens = 16384
# 2025-12-02 16:32:38,664 - tinytroupe - ERROR - [Chat Room] Agent Lisa Carter generated an exception: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# 2025-12-02 16:32:38,665 - tinytroupe - ERROR - [Chat Room] Agent Oscar generated an exception: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
lisa.pp_current_interactions()
# Out:
# **** BEGIN SIMULATION TRAJECTORY FOR Lisa Carter ****
# Agent simulation trajectory event #0:
# >>>>>>>>> Date and time of events: 2025-12-02T16:32:35.627048
# USER --> Lisa Carter: [CONVERSATION]
#           > Talk to Oscar to know more about him
# The last agent simulation trajectory event number was 0, thus the current number of the NEXT POTENTIAL TRAJECTORY
# EVENT is 1.
# **** END SIMULATION TRAJECTORY FOR Lisa Carter ****

# %%
oscar.pp_current_interactions()
# Out:
# **** BEGIN SIMULATION TRAJECTORY FOR Oscar ****
# The last agent simulation trajectory event number was 0, thus the current number of the NEXT POTENTIAL TRAJECTORY
# EVENT is 1.
# **** END SIMULATION TRAJECTORY FOR Oscar ****
